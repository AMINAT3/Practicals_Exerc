# %%
a = 'Chuck'
b = 'hello ' + a 

print(b)
# Out:
# hello Chuck

# %%
hours = 35
rate = 2.75
pay = hours*rate
print(pay)
# Out:
# 96.25

# %%
width = 17
height = 12.0

# %%
width//2
# Out:
# 8

# %%
width/2.0
# Out:
# 8.5

# %%
height/3
# Out:
# 4.0

# %%
8 + 8.5 \* 5
# Out:
#   File "<ipython-input-27-667b26743f02>", line 1
#     8 + 8.5 \* 5
#                 ^
# SyntaxError: unexpected character after line continuation character

# %%
celsius = float(input("Enter temperature in celsius: "))
fahrenheit = (celsius * 9/5) + 32
print('%.2f Celsius is: %0.2f Fahrenheit' %(celsius, fahrenheit))
# Out:
# Enter temperature in celsius:  60
# 60.00 Celsius is: 140.00 Fahrenheit

# %%
celsius = 60
fahrenheit = (celsius *(9/5)) + 32
fahrenheit
# Out:
# 140.0

# %%
hours = 45
rate= 10.5
pay = hours * rate
print(pay)
# Out:
# 472.5

# %% [markdown]
# boolean

# %%
hours = 45
rate = 10

if hours <= 40:
    print(hours * rate)
elif hours>40:
    print(40* rate + (hours-40)*1.5*rate)
# Out:
# 475.0

# %%
score = (">= 0.9, >= 0.8, >= 0.7, >= 0.6, < 0.6")
a = (0.7)
if 0.0 < a > 1.0:
    print(" score of out of range")
elif a >= 0.9:
        print("A")
elif a >= 0.8:
            print(B)
elif a >= 0.7:
                print("C")
elif a >= 0.6:
                    print("D")
elif a < 0.6:
                        print("F")
# Out:
# C

# %%
score = (">= 0.9, >= 0.8, >= 0.7, >= 0.6, < 0.6")
a = (10.0)
if 0.0 < a > 1.0:
    print(" score of out of range")
elif a >= 0.9:
        print("A")
elif a >= 0.8:
            print(B)
elif a >= 0.7:
                print("C")
elif a >= 0.6:
                    print("D")
elif a < 0.6:
                        print("F")
# Out:
#  score of out of range

# %%
num = 0
tot = 0.0
while True:
    number = input("Enter a number")
    if number == 'done':
        break
    try :
        num1 = float(number)
    except:
        print('Invailed Input')
        continue
    num = num+1
    tot = tot + num1
print ('all done')
print (tot,num,tot/num)

# %%
score = (">= 0.9, >= 0.8, >= 0.7, >= 0.6, < 0.6")
a = (10.0)
if 0.0 < a > 1.0:
    print(" error")
elif a >= 0.9:
        print("A")
elif a >= 0.8:
            print(B)
elif a >= 0.7:
                print("C")
elif a >= 0.6:
                    print("D")
elif a < 0.6:
                        print("F")
# Out:
#  error

# %%
num = 6
tot = 6.7
while true: 
    numer = (6)
    if number == 'done':
        break
    try : 
        num1 = (7)
    except :
            print('wrong')
            continue
            num =num+1
            tot =tot + num1
            print ('all done')
print (tot,num,tot/num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-9273dfdb83b7> in <module>
#       1 num = 6
#       2 tot = 6.7
# ----> 3 while true:
#       4     numer = (6)
#       5     if number == 'done':
#
# NameError: name 'true' is not defined

# %%
# [:] means that all latters in fruit should be printed since no value was assing to it 
s = "fruit"
print(s[:])
# Out:
# fruit

# %%
 count = 5
a = 'apple' 
count == a
print(count)
# Out:
# 5

# %%
def countLetters(str, ch):
    fruit = str
count = 0
for char in fruit:
    if char == ch:
count = count + 1
print count
# Out:
#   File "<ipython-input-61-a7ef88cb5040>", line 6
#     count = (count + [1])
#                          ^
# IndentationError: expected an indented block

# %%
def countLetters(str, ch):
    fruit = str
count = 0
for char in fruit:
    if char == ch:
count = count + 1
    print count
# Out:
#   File "<ipython-input-64-6e273bd251eb>", line 6
#     count = count + 1
#                      ^
# IndentationError: expected an indented block

# %% [markdown]
# NUMPY

# %%
# all() returns true if all item in a giving element is true, other wise returns false
# all() returns true if the iterable object is empty

b1 = (1,2,4,6)
print(all(b1))
# Out:
# True

# %%
b2 = (0,0.9,0,8)
print(all(b2))
# Out:
# False

# %%
b3 = ()
print(all(b3))
# Out:
# True

# %%
# any()returns True if at least one item in an iterable is True.
# any() method calculates whether any value in an iterable object a list, string, or tuple is equal to True and returns True,otherwise,
# any() returns False.

p1 = (4, 3, 8, 7)
print(any(p1))
# Out:
# True

# %%
p2= (0,1,2,3)
print(any(p2))
# Out:
# True

# %%
p4 = (0,0,False)
print(any(p4))
# Out:
# False

# %%
# all() checks for all the elements if bool(element) is true or not. 

f1 = (6, 4, 8, 9)
print(all(f1))
# Out:
# True

# %%
f2= (0,7,5,3)
print(all(f2))
# Out:
# False

# %%
f4 = (True,0,False)
print(all(f4))
# Out:
# False

# %%
# cumprod() is used to find the cumulative product of the values seen so far over any axis.

import numpy as np
r = np.array([2, 5, 8])
np.cumprod(r)
# Out:
# array([ 2, 10, 80], dtype=int32)

# %%
f = np.array([[2,5,4],[5,4,9]])
np.cumprod(f)
# Out:
# array([   2,   10,   40,  200,  800, 7200], dtype=int32)

# %%
# cumsum is used to find the cumulative sum of array in a giving element of an axies
 
n = np.array([[2,5,4],[5,4,9]])
np.cumsum(n)
# Out:
# array([ 2,  7, 11, 16, 20, 29], dtype=int32)

# %%
# reshape() is used to give a new shape to an array without changing its data.
import numpy as np

a = np.array([[1,4,5,7],[8,5,6,7],[11,5,9,3],[10,3,5,9]])
a
# Out:
# array([[ 1,  4,  5,  7],
#        [ 8,  5,  6,  7],
#        [11,  5,  9,  3],
#        [10,  3,  5,  9]])

# %%
import math
t = np.array(math.pi/3)
np.cos(t)
f = np.array(math.pi/3)
np.cosh(f)
# Out:
# 1.600286857702386

# %% [markdown]
# EXERCISES

# %%
n = 4
if n % 2 == 1:
    print('weird')
elif n % 2== 0 and n in range (2,5):
    print('not weired')
# elif n%2 == 0:
#      for n in range(6,20:)
#     print('weird')
# else:
#     if (n%2==0 & n.20):
#       print("not werid")
# Out:
# not weired

# %%
i = ()
n = 7
for i in range(0,5):
    print(i**2)
# Out:
# 0
# 1
# 4
# 9
# 16

# %% [markdown]
# string split and join

# %%
a = "this is a string"
a = "-".join(a)
print(a)
# Out:
# t-h-i-s- -i-s- -a- -s-t-r-i-n-g

# %%
b = "i am a girl"
b = b.split(" ") 
print(b)
# Out:
# ['i', 'am', 'a', 'girl']

# %%
b = "-".join(b)
print(b)
# Out:
# i-am-a-girl

# %%
a = "hello world"
b = a.title()
print(b)
# Out:
# Hello World

# %%
b = "chris alin"
x = b.title() 
print(x)
# Out:
# Chris Alin

# %% [markdown]
# NESTED

# %%
students = [['Harry', 37.21], ['Berry', 37.21], ['Tina', 37.2], ['Akriti', 41], ['Harsh', 39]
